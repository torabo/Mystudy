# %% [markdown]
# ## 강의 특징
# - train, test 데이터셋만 주어짐
# - 데이터에 대한 명세는 없다
# - 풀이영상 -> 데이터 컬럼 하나하나의 의미를 살펴보지 않는다.
# - 실제 시험처럼 연습을 하고 싶다면
#     - 하나의 셀에 데이터 로드, EDA, 모델링, 파일저장
#     - 연습시 셀별로 구분지어서 실행
#
# ---
#
# ## 모델 점수 최적화 전략
# - randomforest 3~4개의 파라미터 변경해보기
# - train의 데이터셋 증가
#     - train_test_split의 test_size 줄이기
#     - validation 셋을 나누지 않고 train.csv의 모든데이터로 학습
#
# ---
#
# ## 모델링 플로우
#
# - eda
#     - 결측치 숫자 확인
#     - 범주형 변수 유니크 숫자 확인
#     - 실수형 변수 분포확인
# - 결측치처리
# - 데이터 전처리(옵션)
#     - 이상치 처리
#     - 노이즈 데이터 처리
#     - 날짜형 데이터 처리 (보통 다 제거)
# - 범주형 변수처리
# - train,validation 분할
# - 모델링
# - validation 평가
# - test셋 같은 전처리 반복
# - test 예측
# - 저장

# %% [markdown]
# # 2회

# %% [markdown]
# 데이터 설명 : e-commerce 배송의 정시 도착여부
# 종속변수 Reached.on.Time_Y.N(1: 정시배송 0 : 정시미배송)
#
# ---
#
# train : https://raw.githubusercontent.com/Datamanim/datarepo/main/data/2_train.csv
# test : https://raw.githubusercontent.com/Datamanim/datarepo/main/data/2_test.csv
#
# 평가지표 : f1_score
# 제출 파일의 컬럼은 pred만 존재해야하며 파일명은 result.csv로 하라

# %%
import pandas as pd
train = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/data/2_train.csv')
test = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/data/2_test.csv')

display(train)
display(test)
# Out:
#         ID Warehouse_block Mode_of_Shipment Customer_care_calls  \
# 0     6045               A           Flight                   4
# 1       44               F             Ship                   3
# 2     7940               F             Road                   4
# 3     1596               F             Ship                   4
# 4     4395               A           Flight                   5
# ...    ...             ...              ...                 ...
# 6593  8610               F             Road                   5
# 6594  3390               F             Ship                   4
# 6595  5150               F             Ship                   3
# 6596  3950               F             Road                   4
# 6597  5969               C             Ship                   6
#
#       Customer_rating  Cost_of_the_Product  Prior_purchases  \
# 0                   3                266.0                5
# 1                   1                174.0                2
# ...

# %% [markdown]
# # 라벨인코딩
#
# - 장점
#     - 범주형 변수를 컬럼수를 늘리지 않으면서 정수형으로 변경가능
# - 단점
#     - 정석적인 방법은 아님
#     - 순서를 반영 하지 않는 범주형 변수에 대해 모델이 해석을 어려워 할 수 있음
#         - 하지만! 랜포는 이것마저 고려한다!!

# %% [markdown]
# # 3회
# 여행자 보험 가입여부 분류
# 종속 변수 : TravelInsurance
#
# ---
# train : https://raw.githubusercontent.com/Datamanim/datarepo/main/data/3_train.csv
# test : https://raw.githubusercontent.com/Datamanim/datarepo/main/data/e_test.csv
#
#
#
# TravelInsurance가 1일 확률을 구해서 제출하라. 평가지표 : auc
# 제출 파일의 컬럼은 pred만 존재해야하며 파일명은 result.csv로 하라

# %%
import pandas as pd
train = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/data/3_train.csv')
test = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/data/3_test.csv')

display(train)
display(test)
# Out:
#       Unnamed: 0  Age               Employment Type GraduateOrNot  \
# 0              0   26  Private Sector/Self Employed           Yes
# 1              1   30  Private Sector/Self Employed            No
# 2              2   32             Government Sector           Yes
# 3              3   26  Private Sector/Self Employed           Yes
# 4              4   34  Private Sector/Self Employed            No
# ...          ...  ...                           ...           ...
# 1485        1485   29  Private Sector/Self Employed           Yes
# 1486        1486   31             Government Sector            No
# 1487        1487   29  Private Sector/Self Employed           Yes
# 1488        1488   30  Private Sector/Self Employed            No
# 1489        1489   28  Private Sector/Self Employed           Yes
#
#       AnnualIncome  FamilyMembers  ChronicDiseases FrequentFlyer  \
# 0          1400000            5.0                0            No
# ...

# %% [markdown]
# # 4회
# 유저 타입 분류, 종속변수 Segmentation
#
# ---
# train : https://raw.githubusercontent.com/Datamanim/datarepo/main/data/4_train.csv
# test : https://raw.githubusercontent.com/Datamanim/datarepo/main/data/4_test.csv
#
# Segmentation의 클래스를 예측해서 저장후 제출, 컬럼은 pred
# 평가지표 : macro f1 score
# 제출 파일의 컬럼은 pred만 존재해야하며 파일명은 result.csv로 하라

# %%
import pandas as pd
train = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/data/4_train.csv')
test = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/data/4_test.csv')

display(train)
display(test)
# Out:
#       Unnamed: 0      ID  Gender Ever_Married  Age Graduated     Profession  \
# 0              0  464357    Male           No   40       Yes         Artist
# 1              1  459624    Male           No   18        No     Healthcare
# 2              2  462672    Male           No   25        No     Healthcare
# 3              3  463360  Female          Yes   46       Yes         Artist
# 4              4  462420    Male           No   27       Yes     Healthcare
# ...          ...     ...     ...          ...  ...       ...            ...
# 4876        4876  465496    Male          Yes   84       Yes         Lawyer
# 4877        4877  460946    Male           No   84        No         Artist
# 4878        4878  466118  Female          Yes   40        No       Engineer
# 4879        4879  460729    Male          Yes   36       Yes  Entertainment
# 4880        4880  463270    Male          Yes   52        No      Executive
#
# ...

# %% [markdown]
# # 5회
#
# 벤츠 차량 가격 예측 : https://www.kaggle.com/datasets/mysarahmadbhat/mercedes-used-car-listing
#
# ---
# train : https://raw.githubusercontent.com/Datamanim/datarepo/main/data/5_train.csv
# test : https://raw.githubusercontent.com/Datamanim/datarepo/main/data/5_test.csv
#
# 예측 변수 price
# test.csv에 대해 ID별로 price 값을 예측하여 제출, 제출 데이터 컬럼은 ID와 price 두개만 존재해야함. 평가지표는 rmse

# %%
import pandas as pd
train = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/data/5_train.csv')
test = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/data/5_test.csv')

display(train)
display(test)
# Out:
#          ID      model  year  price transmission  mileage fuelType  tax   mpg  \
# 0     10170    A Class  2012  11940    Automatic    46000   Diesel   30  64.2
# 1      9551   CL Class  2020  38624    Semi-Auto       19   Petrol  150  36.7
# 2      1790    A Class  2013   8500       Manual    69031   Petrol  125  51.4
# 3     10018    B Class  2015  13998    Automatic    34739   Diesel  125  56.5
# 4       142    E Class  2017  20998    Semi-Auto    21352   Diesel   20  72.4
# ...     ...        ...   ...    ...          ...      ...      ...  ...   ...
# 9818   5612    S Class  2016  79950    Semi-Auto    25317   Petrol  570  24.1
# 9819   9661    C Class  2016  16000       Manual    34903   Diesel   20  68.9
# 9820  10521    A Class  2015  11295    Automatic    86890   Diesel   20  64.2
# 9821   9914    A Class  2016  11849       Manual    27958   Diesel    0  80.7
# 9822   1468    C Class  2015  13448    Semi-Auto    31878   Diesel   20  65.7
#
#       engineSize
# ...

# %% [markdown]
# # 6회
#
# 건강 상태 분류문제 : https://www.kaggle.com/datasets/alphiree/cardiovascular-diseases-risk-prediction-dataset
#
# ---
#
# train : https://raw.githubusercontent.com/Datamanim/datarepo/main/data/6_train.csv
# test : https://raw.githubusercontent.com/Datamanim/datarepo/main/data/6_test.csv
#
# 예측 변수 General_Health, test.csv에 대해 ID별로 General_Health 값을 예측하여 제출, 제출 데이터 컬럼은 ID와 General_Health 두개만 존재해야함. 평가지표는 f1score

# %% [markdown]
# - BMI 결측치는 몸무게 / 키** 2으로 변환
# - test셋의 더미화컬럼과 train 더미화 컬럼의 결과값이 동일하지 않음

# %%
import pandas as pd
train = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/data/6_train.csv')
test = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/data/6_test.csv')

display(train)
display(test)
# Out:
#              ID General_Health                  Checkup Exercise  \
# 0       ID_1473           Good  Within the past 2 years      Yes
# 1       ID_2045           Good  Within the past 2 years      Yes
# 2       ID_3079           Good     Within the past year      Yes
# 3      ID_15958      Excellent     Within the past year      Yes
# 4      ID_11047      Excellent     Within the past year      Yes
# ...         ...            ...                      ...      ...
# 11225  ID_10059      Excellent     Within the past year      Yes
# 11226   ID_2220           Good  Within the past 2 years      Yes
# 11227   ID_6545           Fair      5 or more years ago      Yes
# 11228  ID_13725      Excellent     Within the past year      Yes
# 11229   ID_4890           Good     Within the past year       No
#
#       Heart_Disease Skin_Cancer Other_Cancer Depression Diabetes Arthritis  \
# 0                No          No           No         No       No       Yes
# ...

# %% [markdown]
# # 7회
#
#
# 제주업종별카드이용정보 : https://www.jejudatahub.net/data/view/data/1048 후처리
#
# ---
#
# train : https://raw.githubusercontent.com/Datamanim/datarepo/main/data/7_train.csv
# test : https://raw.githubusercontent.com/Datamanim/datarepo/main/data/7_test.csv
#
# 종속변수 :이용금액 , 평가지표 : rmse

# %%
import pandas as pd
train = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/data/7_train.csv')
test = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/data/7_test.csv')

display(train)
display(test)
# Out:
#            ID      연월            업종명 이용자구분    성별   이용자수     이용건수         이용금액
# 0     ID_5020  202201            여관업    법인  알수없음   7693  12105.0  30490.21809
# 1     ID_5021  202201            여관업  제주도민    남성   3990   4291.0   2941.63241
# 2     ID_5022  202201            여관업  제주도민    여성   1495   1620.0   1192.77191
# 3     ID_5023  202201    전시 및 행사 대행업   내국인    남성  16299  18588.0   4329.33220
# 4     ID_5024  202201    전시 및 행사 대행업   내국인    여성  17350  19922.0   3963.16520
# ...       ...     ...            ...   ...   ...    ...      ...          ...
# 2240  ID_7260  202310  화장품 및 방향제 소매업   동남아  알수없음     56     67.0    313.88700
# 2241  ID_7261  202310  화장품 및 방향제 소매업    법인  알수없음    488    521.0   1279.84145
# 2242  ID_7262  202310  화장품 및 방향제 소매업  제주도민    남성   1318   1410.0   1030.54160
# 2243  ID_7263  202310  화장품 및 방향제 소매업  제주도민    여성   2611   2798.0   1958.16205
# 2244  ID_7264  202310  화장품 및 방향제 소매업    중국  알수없음    169    205.0    418.15300
#
# [2245 rows x 8 columns]
# ...

# %% [markdown]
# # 8회
#
# 날씨에 따른 지하철 이용자수
#
# ---
# train : https://raw.githubusercontent.com/Datamanim/datarepo/main/data/8_train.csv
# test : https://raw.githubusercontent.com/Datamanim/datarepo/main/data/8_test.csv
# 종속변수 :Y , 평가지표 : mae

# %%
import pandas as pd
train = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/data/8_train.csv')
test = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/data/8_test.csv')

display(train)
display(test)
# Out:
#        C1   C2   C3    C4        Date  Weekday  Temperature   Humidity  \
# 0     X_2  Y_0  Z_3   W_2  2023-03-27        0    10.533315  88.101605
# 1     X_0  Y_3  Z_2   W_9  2023-10-12        3    -1.698046  42.811039
# 2     X_0  Y_4  Z_3   W_5  2023-03-01        2     6.705572  30.026276
# 3     X_2  Y_4  Z_6   W_5  2023-02-23        3    13.500946  70.672815
# 4     X_2  Y_3  Z_2   W_3  2023-04-03        0    -7.600114  33.941831
# ...   ...  ...  ...   ...         ...      ...          ...        ...
# 3929  X_1  Y_1  Z_3  W_10  2023-09-10        6    23.835041  50.510106
# 3930  X_0  Y_4  Z_2   W_2  2023-01-07        5    -3.109891  65.583128
# 3931  X_0  Y_4  Z_6  W_11  2023-06-18        6     7.808777  34.416581
# 3932  X_1  Y_4  Z_3   W_0  2023-05-10        2    19.520365  42.189440
# 3933  X_1  Y_4  Z_3   W_3  2023-05-18        3    27.276605  11.708886
#
#       Wind_Speed  Precipitation     Pressure  Visibility   Y
# ...

# %% [markdown]
# # 9회
# - 종속변수 : 작업_유형
# - 평가 지표 f1-score

# %%
import pandas as pd
train = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/refs/heads/master/krdatacertificate/10/t2_train.csv')
test = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/refs/heads/master/krdatacertificate/10/t2_test.csv')

display(train.head(2))
display(test.head(2))
# Out:
#    지역 작물명 작물_분류 작업_상위_분류 등급 연속_작업_여부  작업_연도  작업_소요_일수  작업_순서      재배면적  \
# 0  충청   벼    곡물       수확  B        예   2019      16.0      4  43339.45
# 1  전라   벼    곡물       방제  C        예   2020      28.0      1  96435.53
#
#      작업_시작_일자  평균_기온  작업자_수  작업_유형
# 0  2023-11-03  17.90      3      1
# 1  2023-07-29  15.24      5      0
#    지역 작물명 작물_분류 작업_상위_분류 등급 연속_작업_여부  작업_연도  작업_소요_일수  작업_순서      재배면적  \
# 0  강원  감자    곡물       방제  A        예   2021       6.0      1  27783.73
# 1  전라   벼    채소       수확  C      아니오   2021       4.0      2   7695.25
#
#      작업_시작_일자  평균_기온  작업자_수
# 0  2023-12-23  20.89     12
# 1  2023-11-01  18.74      2
